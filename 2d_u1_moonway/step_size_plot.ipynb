# %%
from lametlat.utils.plot_settings import *
import matplotlib.pyplot as plt
import numpy as np

# %%
ft_step_size_ls = np.arange(0.05, 0.16, 0.01)
autocorr_ls = [0.88, 0.89, 0.73, 0.88, 0.825, 0.87, 0.93, 0.93, 1, 1, 1]
accept_rate_ls = [0.8965, 0.8604, 0.7812, 0.7402, 0.6338, 0.4180, 0.2373, 0.0498, 0.0010, 0.0000, 0.0000]

fig, ax = default_plot()
ax.plot(ft_step_size_ls, autocorr_ls, label='beta = 6.0')
ax.hlines(0.905, 0.05, 0.16, color='k', linestyle='--', label='HMC')
ax.legend(**fs_small_p)
ax.set_xlabel('Step Size of FT HMC', **fs_p)
ax.set_ylabel('Autocorrelation', **fs_p)
plt.tight_layout()
plt.show()

fig, ax = default_plot()
ax.plot(ft_step_size_ls, accept_rate_ls, label='beta = 6.0')
ax.hlines(0.7520, 0.05, 0.16, color='k', linestyle='--', label='HMC')
ax.legend(**fs_small_p)
ax.set_title('train beta = 6.0', **fs_p)
ax.set_xlabel('Step Size of FT HMC', **fs_p)
ax.set_ylabel('Acceptance Rate', **fs_p)
plt.tight_layout()
plt.show()

# %%
ft_step_size_ls = np.arange(0.05, 0.16, 0.01)
autocorr_ls = [0.85, 0.9, 0.905, 0.945, 0.83, 0.825, 0.81, 0.89, 0.73, 0.905, 0.62]
accept_rate_ls = [0.9316, 0.8984, 0.8623, 0.8057, 0.7480, 0.6738, 0.5996, 0.3262, 0.1992, 0.0586, 0.0088]

fig, ax = default_plot()
ax.plot(ft_step_size_ls, autocorr_ls, label='beta = 6.0')
ax.hlines(0.905, 0.05, 0.16, color='k', linestyle='--', label='HMC')
ax.legend(**fs_small_p)
ax.set_xlabel('Step Size of FT HMC', **fs_p)
ax.set_ylabel('Autocorrelation', **fs_p)
plt.tight_layout()
plt.show()

fig, ax = default_plot()
ax.plot(ft_step_size_ls, accept_rate_ls, label='beta = 6.0')
ax.hlines(0.7520, 0.05, 0.16, color='k', linestyle='--', label='HMC')
ax.legend(**fs_small_p)
ax.set_title('train beta = 4.0', **fs_p)
ax.set_xlabel('Step Size of FT HMC', **fs_p)
ax.set_ylabel('Acceptance Rate', **fs_p)
plt.tight_layout()
plt.show()

# %%
ft_step_size_ls = np.arange(0.05, 0.16, 0.01)
autocorr_ls = [0.72, 0.65, 0.67, 0.72, 0.815, 0.52, 0.825, 0.825, 0.72, 0.84, 0.95]
accept_rate_ls = [0.9336, 0.8916, 0.8477, 0.7939, 0.7471, 0.6982, 0.5498, 0.4219, 0.1719, 0.0781, 0.0117]

fig, ax = default_plot()
ax.plot(ft_step_size_ls, autocorr_ls, label='beta = 5.5')
ax.hlines(0.8, 0.05, 0.16, color='k', linestyle='--', label='HMC')
ax.legend(**fs_small_p)
ax.set_xlabel('Step Size of FT HMC', **fs_p)
ax.set_ylabel('Autocorrelation', **fs_p)
plt.tight_layout()
plt.show()

fig, ax = default_plot()
ax.plot(ft_step_size_ls, accept_rate_ls, label='beta = 5.5')
ax.hlines(0.7666, 0.05, 0.16, color='k', linestyle='--', label='HMC')
ax.legend(**fs_small_p)
ax.set_title('train beta = 4.0', **fs_p)
ax.set_xlabel('Step Size of FT HMC', **fs_p)
ax.set_ylabel('Acceptance Rate', **fs_p)
plt.tight_layout()
plt.show()
